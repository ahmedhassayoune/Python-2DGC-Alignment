# %%
import netCDF4 as nc
import numpy as np
import read_chroma
import plot
import math
import peak_simulation
import random
import importlib
import os
import traceback
import mass_spec
import json
import matplotlib.pyplot as plt
import importlib
import baseline_correction
from skimage.restoration import estimate_sigma

# %% [markdown]
# # Chromato Simulation

# %%
chromato_obj=read_chroma.read_chroma('F:/Bureau/032023-data-Tenax-VOC-COVID/801850-A-C-01-157-split10.cdf')
chromato_no_baseline=baseline_correction.chromato_no_baseline(chromato_obj[0])
sigma = estimate_sigma(chromato_no_baseline, channel_axis=None)
print(sigma)
# Out:
# 5882.485560480358

# %%
plot.visualizer(chromato_obj=(chromato_obj[0],chromato_obj[1]), log_chromato=False)
plot.visualizer(chromato_obj=(chromato_no_baseline,chromato_obj[1]), log_chromato=False)

# %%
plot.visualizer(chromato_obj=(chromato_no_baseline,chromato_obj[1]), log_chromato=False)
plot.visualizer(chromato_obj=(chromato_no_baseline,chromato_obj[1]), log_chromato=True)
plot.visualizer(chromato_obj=(chromato_no_baseline,chromato_obj[1]), log_chromato=False, center_pt=[200,50], center_pt_window_1=30, center_pt_window_2=30)
plot.visualizer(chromato_obj=(chromato_no_baseline,chromato_obj[1]), log_chromato=True, center_pt=[200,50], center_pt_window_1=30, center_pt_window_2=30)
# Out:
# c:\Users\Stan\pic\plot.py:356: RuntimeWarning: divide by zero encountered in log
#   chromato = np.log(chromato)

# %%
new_cdf_path="G:/SIMULATION/"

# %%
importlib.reload(peak_simulation)
cdf_name="test"
#params=peak_simulation.simulation_from_cdf_model(min_overlap=0.1, max_overlap=0.35, cdf_name=cdf_name, model_filename='F:/Bureau/032023-data-Tenax-VOC-COVID/801850-A-C-01-157-split10.cdf', new_cdf_path=new_cdf_path, lib_path='./lib_EIB_gt.mgf', intensity_range_min=60000000, intensity_range_max=90000000)
#params=peak_simulation.simulation_from_cdf_model(min_overlap=0.35, max_overlap=0.70, cdf_name=cdf_name, model_filename='F:/Bureau/032023-data-Tenax-VOC-COVID/801850-A-C-01-157-split10.cdf', new_cdf_path=new_cdf_path, lib_path='./lib_EIB_gt.mgf', intensity_range_min=60000000, intensity_range_max=90000000)
params=peak_simulation.simulation_from_cdf_model(noise_loc=1000.0, noise_scale=500.0, min_overlap=0.70, max_overlap=0.99, cdf_name=cdf_name, model_filename='F:/Bureau/032023-data-Tenax-VOC-COVID/801850-A-C-01-157-split10.cdf', new_cdf_path=new_cdf_path, lib_path='./lib_EIB_gt.mgf', intensity_range_min=60000000, intensity_range_max=90000000)
# Out:
# 1/14 1/6
# 1/14 2/6
# 1/14 3/6
# 1/14 4/6
# 1/14 5/6
# 1/14 6/6
# 2/14 1/6
# 2/14 2/6
# 2/14 3/6
# 2/14 4/6
# 2/14 5/6
# 2/14 6/6
# 3/14 1/6
# 3/14 2/6
# 3/14 3/6
# 3/14 4/6
# 3/14 5/6
# 3/14 6/6
# 4/14 1/6
# 4/14 2/6
# 4/14 3/6
# 4/14 4/6
# 4/14 5/6
# 4/14 6/6
# 5/14 1/6
# 5/14 2/6
# 5/14 3/6
# 5/14 4/6
# 5/14 5/6
# 5/14 6/6
# 6/14 1/6
# 6/14 2/6
# 6/14 3/6
# 6/14 4/6
# 6/14 5/6
# 6/14 6/6
# 7/14 1/6
# 7/14 2/6
# 7/14 3/6
# 7/14 4/6
# 7/14 5/6
# 7/14 6/6
# 8/14 1/6
# 8/14 2/6
# 8/14 3/6
# 8/14 4/6
# 8/14 5/6
# 8/14 6/6
# 9/14 1/6
# 9/14 2/6
# 9/14 3/6
# 9/14 4/6
# 9/14 5/6
# 9/14 6/6
# 10/14 1/6
# 10/14 2/6
# 10/14 3/6
# 10/14 4/6
# 10/14 5/6
# 10/14 6/6
# 11/14 1/6
# 11/14 2/6
# 11/14 3/6
# 11/14 4/6
# 11/14 5/6
# 11/14 6/6
# 12/14 1/6
# 12/14 2/6
# 12/14 3/6
# 12/14 4/6
# 12/14 5/6
# 12/14 6/6
# 13/14 1/6
# 13/14 2/6
# 13/14 3/6
# 13/14 4/6
# 13/14 5/6
# 13/14 6/6
# 14/14 1/6
# 14/14 2/6
# 14/14 3/6
# 14/14 4/6
# 14/14 5/6
# 14/14 6/6
# 13 499
# ...

# %%
chromato_obj_new=read_chroma.read_chroma('G:/SIMULATION/test.cdf')
chromato_no_bl_2=baseline_correction.chromato_no_baseline(chromato_obj_new[0])
sigma2 = estimate_sigma(chromato_no_bl_2, channel_axis=None)
print(sigma, sigma2)
# Out:
# 5882.485560480358 9639.752562547777

# %%
importlib.reload(peak_simulation)
'''cdf_name="loc_1000_scale_500_poisson_09"
params=peak_simulation.simulation_from_cdf_model(min_overlap=0.50, max_overlap=0.90, cdf_name=cdf_name, model_filename='F:/Bureau/032023-data-Tenax-VOC-COVID/801850-A-C-01-157-split10.cdf', new_cdf_path=new_cdf_path, lib_path='./lib_EIB_gt.mgf', intensity_range_min=60000000, intensity_range_max=90000000, noise_loc=1000.0, noise_scale=500.0)
cdf_name="loc_1500_scale_500_poisson_09"
params=peak_simulation.simulation_from_cdf_model(min_overlap=0.50, max_overlap=0.90, cdf_name=cdf_name, model_filename='F:/Bureau/032023-data-Tenax-VOC-COVID/801850-A-C-01-157-split10.cdf', new_cdf_path=new_cdf_path, lib_path='./lib_EIB_gt.mgf', intensity_range_min=60000000, intensity_range_max=90000000, noise_loc=1500.0, noise_scale=500.0)
cdf_name="loc_2000_scale_500_poisson_09"
params=peak_simulation.simulation_from_cdf_model(min_overlap=0.50, max_overlap=0.90, cdf_name=cdf_name, model_filename='F:/Bureau/032023-data-Tenax-VOC-COVID/801850-A-C-01-157-split10.cdf', new_cdf_path=new_cdf_path, lib_path='./lib_EIB_gt.mgf', intensity_range_min=60000000, intensity_range_max=90000000, noise_loc=2000.0, noise_scale=500.0)
'''
cdf_name="loc_4000_scale_500_poisson_09"
params=peak_simulation.simulation_from_cdf_model(min_overlap=0.50, max_overlap=0.90, cdf_name=cdf_name, model_filename='F:/Bureau/032023-data-Tenax-VOC-COVID/801850-A-C-01-157-split10.cdf', new_cdf_path=new_cdf_path, lib_path='./lib_EIB_gt.mgf', intensity_range_min=60000000, intensity_range_max=90000000, noise_loc=4000.0, noise_scale=500.0)
cdf_name="loc_8000_scale_500_poisson_09"
params=peak_simulation.simulation_from_cdf_model(min_overlap=0.50, max_overlap=0.90, cdf_name=cdf_name, model_filename='F:/Bureau/032023-data-Tenax-VOC-COVID/801850-A-C-01-157-split10.cdf', new_cdf_path=new_cdf_path, lib_path='./lib_EIB_gt.mgf', intensity_range_min=60000000, intensity_range_max=90000000, noise_loc=8000.0, noise_scale=500.0)
# Out:
# 1/14 1/6
# 1/14 2/6
# 1/14 3/6
# 1/14 4/6
# 1/14 5/6
# 1/14 6/6
# 2/14 1/6
# 2/14 2/6
# 2/14 3/6
# 2/14 4/6
# 2/14 5/6
# 2/14 6/6
# 3/14 1/6
# 3/14 2/6
# 3/14 3/6
# 3/14 4/6
# 3/14 5/6
# 3/14 6/6
# 4/14 1/6
# 4/14 2/6
# 4/14 3/6
# 4/14 4/6
# 4/14 5/6
# 4/14 6/6
# 5/14 1/6
# 5/14 2/6
# 5/14 3/6
# 5/14 4/6
# 5/14 5/6
# 5/14 6/6
# 6/14 1/6
# 6/14 2/6
# 6/14 3/6
# 6/14 4/6
# 6/14 5/6
# 6/14 6/6
# 7/14 1/6
# 7/14 2/6
# 7/14 3/6
# 7/14 4/6
# 7/14 5/6
# 7/14 6/6
# 8/14 1/6
# 8/14 2/6
# 8/14 3/6
# 8/14 4/6
# 8/14 5/6
# 8/14 6/6
# 9/14 1/6
# 9/14 2/6
# 9/14 3/6
# 9/14 4/6
# 9/14 5/6
# 9/14 6/6
# 10/14 1/6
# 10/14 2/6
# 10/14 3/6
# 10/14 4/6
# 10/14 5/6
# 10/14 6/6
# 11/14 1/6
# 11/14 2/6
# 11/14 3/6
# 11/14 4/6
# 11/14 5/6
# 11/14 6/6
# 12/14 1/6
# 12/14 2/6
# 12/14 3/6
# 12/14 4/6
# 12/14 5/6
# 12/14 6/6
# 13/14 1/6
# 13/14 2/6
# 13/14 3/6
# 13/14 4/6
# 13/14 5/6
# 13/14 6/6
# 14/14 1/6
# 14/14 2/6
# 14/14 3/6
# 14/14 4/6
# 14/14 5/6
# 14/14 6/6
# ...

# %%
cdf_name="loc_2000_scale_500_poisson_12_overlap_07_099"
params=peak_simulation.simulation_from_cdf_model(noise_loc=2000.0, noise_scale=500.0, poisson_rep=1.2, min_overlap=0.70, max_overlap=0.99, cdf_name=cdf_name, model_filename='F:/Bureau/032023-data-Tenax-VOC-COVID/801850-A-C-01-157-split10.cdf', new_cdf_path=new_cdf_path, lib_path='./lib_EIB_gt.mgf', intensity_range_min=60000000, intensity_range_max=90000000)
cdf_name="loc_2000_scale_500_poisson_15_overlap_07_099"
params=peak_simulation.simulation_from_cdf_model(noise_loc=2000.0, noise_scale=500.0, poisson_rep=1.5, min_overlap=0.70, max_overlap=0.99, cdf_name=cdf_name, model_filename='F:/Bureau/032023-data-Tenax-VOC-COVID/801850-A-C-01-157-split10.cdf', new_cdf_path=new_cdf_path, lib_path='./lib_EIB_gt.mgf', intensity_range_min=60000000, intensity_range_max=90000000)
cdf_name="loc_2000_scale_500_poisson_18_overlap_07_099"
params=peak_simulation.simulation_from_cdf_model(noise_loc=2000.0, noise_scale=500.0, poisson_rep=1.8, min_overlap=0.70, max_overlap=0.99, cdf_name=cdf_name, model_filename='F:/Bureau/032023-data-Tenax-VOC-COVID/801850-A-C-01-157-split10.cdf', new_cdf_path=new_cdf_path, lib_path='./lib_EIB_gt.mgf', intensity_range_min=60000000, intensity_range_max=90000000)
cdf_name="loc_2000_scale_500_poisson_21_overlap_07_099"
params=peak_simulation.simulation_from_cdf_model(noise_loc=2000.0, noise_scale=500.0, poisson_rep=2.1, min_overlap=0.70, max_overlap=0.99, cdf_name=cdf_name, model_filename='F:/Bureau/032023-data-Tenax-VOC-COVID/801850-A-C-01-157-split10.cdf', new_cdf_path=new_cdf_path, lib_path='./lib_EIB_gt.mgf', intensity_range_min=60000000, intensity_range_max=90000000)
print("--------------")
# Out:
# 1/14 1/6
# 1/14 2/6
# 1/14 3/6
# 1/14 4/6
# 1/14 5/6
# 1/14 6/6
# 2/14 1/6
# 2/14 2/6
# 2/14 3/6
# 2/14 4/6
# 2/14 5/6
# 2/14 6/6
# 3/14 1/6
# 3/14 2/6
# 3/14 3/6
# 3/14 4/6
# 3/14 5/6
# 3/14 6/6
# 4/14 1/6
# 4/14 2/6
# 4/14 3/6
# 4/14 4/6
# 4/14 5/6
# 4/14 6/6
# 5/14 1/6
# 5/14 2/6
# 5/14 3/6
# 5/14 4/6
# 5/14 5/6
# 5/14 6/6
# 6/14 1/6
# 6/14 2/6
# 6/14 3/6
# 6/14 4/6
# 6/14 5/6
# 6/14 6/6
# 7/14 1/6
# 7/14 2/6
# 7/14 3/6
# 7/14 4/6
# 7/14 5/6
# 7/14 6/6
# 8/14 1/6
# 8/14 2/6
# 8/14 3/6
# 8/14 4/6
# 8/14 5/6
# 8/14 6/6
# 9/14 1/6
# 9/14 2/6
# 9/14 3/6
# 9/14 4/6
# 9/14 5/6
# 9/14 6/6
# 10/14 1/6
# 10/14 2/6
# 10/14 3/6
# 10/14 4/6
# 10/14 5/6
# 10/14 6/6
# 11/14 1/6
# 11/14 2/6
# 11/14 3/6
# 11/14 4/6
# 11/14 5/6
# 11/14 6/6
# 12/14 1/6
# 12/14 2/6
# 12/14 3/6
# 12/14 4/6
# 12/14 5/6
# 12/14 6/6
# 13/14 1/6
# 13/14 2/6
# 13/14 3/6
# 13/14 4/6
# 13/14 5/6
# 13/14 6/6
# 14/14 1/6
# 14/14 2/6
# 14/14 3/6
# 14/14 4/6
# 14/14 5/6
# 14/14 6/6
# 14 499
# ...

# %%
'''cdf_name="loc_1000_scale_500_poisson_12"
params=peak_simulation.simulation_from_cdf_model(noise_loc=1000.0, noise_scale=500.0, poisson_rep=1.2, min_overlap=0.50, max_overlap=0.90, cdf_name=cdf_name, model_filename='F:/Bureau/032023-data-Tenax-VOC-COVID/801850-A-C-01-157-split10.cdf', new_cdf_path=new_cdf_path, lib_path='./lib_EIB_gt.mgf', intensity_range_min=60000000, intensity_range_max=90000000)
cdf_name="loc_1000_scale_500_poisson_15"
params=peak_simulation.simulation_from_cdf_model(noise_loc=1000.0, noise_scale=500.0, poisson_rep=1.5, min_overlap=0.50, max_overlap=0.90, cdf_name=cdf_name, model_filename='F:/Bureau/032023-data-Tenax-VOC-COVID/801850-A-C-01-157-split10.cdf', new_cdf_path=new_cdf_path, lib_path='./lib_EIB_gt.mgf', intensity_range_min=60000000, intensity_range_max=90000000)'''
cdf_name="loc_1000_scale_500_poisson_18"
params=peak_simulation.simulation_from_cdf_model(noise_loc=1000.0, noise_scale=500.0, poisson_rep=1.8, min_overlap=0.50, max_overlap=0.90, cdf_name=cdf_name, model_filename='F:/Bureau/032023-data-Tenax-VOC-COVID/801850-A-C-01-157-split10.cdf', new_cdf_path=new_cdf_path, lib_path='./lib_EIB_gt.mgf', intensity_range_min=60000000, intensity_range_max=90000000)
'''cdf_name="loc_1000_scale_500_poisson_21"
params=peak_simulation.simulation_from_cdf_model(noise_loc=1000.0, noise_scale=500.0, poisson_rep=2.1, min_overlap=0.50, max_overlap=0.90, cdf_name=cdf_name, model_filename='F:/Bureau/032023-data-Tenax-VOC-COVID/801850-A-C-01-157-split10.cdf', new_cdf_path=new_cdf_path, lib_path='./lib_EIB_gt.mgf', intensity_range_min=60000000, intensity_range_max=90000000)
print("--------------")'''
# Out:
# 1/14 1/6
# 1/14 2/6
# 1/14 3/6
# 1/14 4/6
# 1/14 5/6
# 1/14 6/6
# 2/14 1/6
# 2/14 2/6
# 2/14 3/6
# 2/14 4/6
# 2/14 5/6
# 2/14 6/6
# 3/14 1/6
# 3/14 2/6
# 3/14 3/6
# 3/14 4/6
# 3/14 5/6
# 3/14 6/6
# 4/14 1/6
# 4/14 2/6
# 4/14 3/6
# 4/14 4/6
# 4/14 5/6
# 4/14 6/6
# 5/14 1/6
# 5/14 2/6
# 5/14 3/6
# 5/14 4/6
# 5/14 5/6
# 5/14 6/6
# 6/14 1/6
# 6/14 2/6
# 6/14 3/6
# 6/14 4/6
# 6/14 5/6
# 6/14 6/6
# 7/14 1/6
# 7/14 2/6
# 7/14 3/6
# 7/14 4/6
# 7/14 5/6
# 7/14 6/6
# 8/14 1/6
# 8/14 2/6
# 8/14 3/6
# 8/14 4/6
# 8/14 5/6
# 8/14 6/6
# 9/14 1/6
# 9/14 2/6
# 9/14 3/6
# 9/14 4/6
# 9/14 5/6
# 9/14 6/6
# 10/14 1/6
# 10/14 2/6
# 10/14 3/6
# 10/14 4/6
# 10/14 5/6
# 10/14 6/6
# 11/14 1/6
# 11/14 2/6
# 11/14 3/6
# 11/14 4/6
# 11/14 5/6
# 11/14 6/6
# 12/14 1/6
# 12/14 2/6
# 12/14 3/6
# 12/14 4/6
# 12/14 5/6
# 12/14 6/6
# 13/14 1/6
# 13/14 2/6
# 13/14 3/6
# 13/14 4/6
# 13/14 5/6
# 13/14 6/6
# 14/14 1/6
# 14/14 2/6
# 14/14 3/6
# 14/14 4/6
# 14/14 5/6
# 14/14 6/6
# 12 499
# ...

# %%
for loc in [1000, 1500, 2000, 4000, 8000]:
    chromato_obj_new=read_chroma.read_chroma('G:/SIMULATION/loc_' + str(loc) + '_scale_500_poisson_09.cdf')
    chromato_no_bl_2=baseline_correction.chromato_no_baseline(chromato_obj_new[0])
    sigma2 = estimate_sigma(chromato_no_bl_2, channel_axis=None)
    print(sigma, sigma2)
# Out:
# 5882.485560480358 5828.641839158555
# 5882.485560480358 7669.967225177445
# 5882.485560480358 9727.970868822786
# 5882.485560480358 18276.51664447125
# 5882.485560480358 36013.23350934053

# %%
np.max(chromato_no_baseline), np.max(chromato_no_bl_2), np.max(chromato_no_baseline) / np.max(chromato_no_bl_2)
# Out:
# (177726783.30202276, 179249340.36908764, 0.9915059265270945)

# %%
seuil=5
(seuil * sigma * 100 / np.max(chromato_no_baseline)), (seuil * sigma2 * 100 / np.max(chromato_no_bl_2))
# Out:
# (0.01654923768716352, 0.015424166787988962)

# %%
plot.visualizer(chromato_obj=(chromato_obj_new[0],chromato_obj_new[1]), log_chromato=False)
plot.visualizer(chromato_obj=(chromato_obj_new[0],chromato_obj_new[1]), log_chromato=True)
plot.visualizer(chromato_obj=(chromato_obj_new[0],chromato_obj_new[1]), log_chromato=False, center_pt=[200,50], center_pt_window_1=30, center_pt_window_2=30)
plot.visualizer(chromato_obj=(chromato_obj_new[0],chromato_obj_new[1]), log_chromato=True, center_pt=[200,50], center_pt_window_1=30, center_pt_window_2=30)

# %% [markdown]
# # Test noise

# %%
#chromato_obj_model=read_chroma.read_chroma(filename='./data/ELO_CDF/model.cdf',mod_time= 1.25)
chromato_obj_model=read_chroma.read_chroma(filename='F:/Bureau/032023-data-Tenax-VOC-COVID/801850-A-C-01-157-split10.cdf',mod_time= 1.25)
chromato_model_no_bl=baseline_correction.chromato_no_baseline(chromato_obj_model[0])

# %%
chromato_obj=read_chroma.read_chroma(filename="G:/SIMULATION/loc_1000_scale_500_poisson_09.cdf",mod_time= 1.25)

# %%
chromato_model_noise=chromato_model_no_bl[0:, :]
chromato_model_noise=np.log(chromato_model_noise+1)
plot.visualizer(chromato_obj=(chromato_model_noise,chromato_obj_model[1]), log_chromato=False)
_ = plt.hist(chromato_model_noise, bins='auto')

# %%
chromato_noise=chromato_obj[0][0:, :]
chromato_noise=np.log(chromato_noise+1)
plot.visualizer(chromato_obj=(chromato_noise,chromato_obj_model[1]), log_chromato=False)
_ = plt.hist(chromato_noise, bins='auto')

# %%
print(np.max(np.exp(np.log(chromato_model_noise)))), print(np.max(chromato_model_noise))
print("-----------------")
print(np.max(np.exp(np.log(chromato_noise)))), print(np.max(chromato_noise))
# Out:
# 69294411.535537
# 69294411.53553694
# C:\Users\33631\AppData\Local\Temp\ipykernel_255424\3294111890.py:1: RuntimeWarning: divide by zero encountered in log
#   print(np.max(np.exp(np.log(chromato_noise)))), print(np.max(chromato_noise))
# (None, None)

# %%
chromato_model_noise=chromato_model_noise[100:150, 20:50]
chromato_model_noise=np.log(chromato_model_noise+1)
plot.visualizer(chromato_obj=(chromato_model_noise,chromato_obj_model[1]), log_chromato=False)
_ = plt.hist(chromato_model_noise, bins='auto')

# %%
chromato_noise=chromato_obj[0][100:150, 20:50]
chromato_noise=np.log(chromato_noise+1)
plot.visualizer(chromato_obj=(chromato_noise,chromato_obj_model[1]), log_chromato=False)
_ = plt.hist(chromato_noise, bins='auto')

# %%
chromato_model_noise=chromato_model_noise[100:150, 20:50]
plot.visualizer(chromato_obj=(chromato_model_noise,chromato_obj_model[1]), log_chromato=False)
_ = plt.hist(chromato_model_noise, bins='auto')

# %%
chromato_noise=chromato_model_noise[100:150, 20:50]
plot.visualizer(chromato_obj=(chromato_noise,chromato_obj_model[1]), log_chromato=False)
_ = plt.hist(chromato_noise, bins='auto')

# %%
s = np.random.poisson(0.7, 200000)
id_g=np.concatenate(np.argwhere(s > 0))
s[id_g]=np.random.normal(loc=10.0, scale=3.0, size=len(id_g))
_ = plt.hist(s, bins='auto')

# %%
s = np.random.poisson(1.5, 200000)
id_g=np.concatenate(np.argwhere(s > 0))
s[id_g]=np.random.poisson(4, len(id_g))
_ = plt.hist(s, bins='auto')
